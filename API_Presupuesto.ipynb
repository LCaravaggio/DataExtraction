# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/DataExtraction/blob/main/API_Presupuesto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
from google.colab import userdata
user_key=userdata.get('PRESUPUESTO_KEY')

# %%
url= 'https://www.presupuestoabierto.gob.ar/api/v1/credito'

headers = {"Authorization": user_key, 'Content-Type': 'application/json'}

data = {
    "title": "Credito vigente por jurisdiccion",
    "columns": [
        "jurisdiccion_id",
        "jurisdiccion_desc",
        "credito_vigente"
    ]
}

response = requests.post(url, headers=headers, json=data)

# %%
response.text
# Out:
# '\ufeffjurisdiccion_id,jurisdiccion_desc,credito_vigente\n1,Poder Legislativo Nacional,556729.228334\n5,Poder Judicial de la Nación,1429985.888829\n10,Ministerio Público,576442.906169\n20,Presidencia de la Nación,313178.427356\n25,Jefatura de Gabinete de Ministros,1966673.04013\n35,"Ministerio de Relaciones Exteriores, Comercio Internacional y Culto",520578.52239\n40,Ministerio de Justicia,167556.677004\n41,Ministerio de Seguridad Nacional,5129939.824942\n45,Ministerio de Defensa,3948767.613653\n50,Ministerio de Economía,6360349.297149\n80,Ministerio de Salud,5418186.128058\n88,Ministerio de Capital Humano,50085610.616166\n89,Ministerio de Desregulación y Transformación del Estado,13254.515002\n90,Servicio de la Deuda Pública,10299240.690453\n91,Obligaciones a Cargo del Tesoro,7803446.343509\n'

# %%
import pandas as pd
from io import StringIO

pd.read_csv(StringIO(response.text))
# Out:
#     jurisdiccion_id                                  jurisdiccion_desc  \
# 0                 1                         Poder Legislativo Nacional
# 1                 5                        Poder Judicial de la Nación
# 2                10                                 Ministerio Público
# 3                20                           Presidencia de la Nación
# 4                25                  Jefatura de Gabinete de Ministros
# 5                35  Ministerio de Relaciones Exteriores, Comercio ...
# 6                40                             Ministerio de Justicia
# 7                41                   Ministerio de Seguridad Nacional
# 8                45                              Ministerio de Defensa
# 9                50                             Ministerio de Economía
# 10               80                                Ministerio de Salud
# 11               88                       Ministerio de Capital Humano
# 12               89  Ministerio de Desregulación y Transformación d...
# 13               90                       Servicio de la Deuda Pública
# 14               91                    Obligaciones a Cargo del Tesoro
#
#     credito_vigente
# 0      5.567292e+05
# 1      1.429986e+06
# 2      5.764429e+05
# 3      3.131784e+05
# 4      1.966673e+06
# 5      5.205785e+05
# 6      1.675567e+05
# 7      5.129940e+06
# 8      3.948768e+06
# 9      6.360349e+06
# 10     5.418186e+06
# 11     5.008561e+07
# 12     1.325452e+04
# 13     1.029924e+07
# 14     7.803446e+06
