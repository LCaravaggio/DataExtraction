# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/DataExtraction/blob/main/Alphacast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bajar base entera

# %%
from google.colab import userdata
API_key=userdata.get('ALPHACAST')

# %%
import requests
import pandas as pd
from io import StringIO

url_base='https://api.alphacast.io/datasets'
dataset='5359'
url = url_base + f'/{dataset}/data?apiKey={API_key}&$format=csv'

r1 = requests.get(url)

# %%
data = StringIO(r1.text)
df = pd.read_csv(data, delimiter=',')

# %%
df[-10:]
# Out:
#             Date    country  AA22     AE38  AE38D     AL29  AL29D     AL30  \
# 5086  2025-06-03  Argentina   NaN  85200.0  71.72  87900.0  74.00  80990.0
# 5087  2025-06-04  Argentina   NaN  84920.0  71.01  87800.0  73.64  80750.0
# 5088  2025-06-05  Argentina   NaN  84050.0  70.50  87050.0  72.92  80180.0
# 5089  2025-06-06  Argentina   NaN  84390.0  70.82  87880.0  73.78  80380.0
# 5090  2025-06-09  Argentina   NaN  84450.0  70.99  88410.0  74.20  80990.0
# 5091  2025-06-10  Argentina   NaN  85600.0  72.10  88780.0  74.40  81700.0
# 5092  2025-06-11  Argentina   NaN  85770.0  72.28  88030.0  74.12  81250.0
# 5093  2025-06-12  Argentina   NaN  85200.0  71.80  87690.0  74.05  81230.0
# 5094  2025-06-13  Argentina   NaN  84420.0  71.09  86810.0  73.01  79810.0
# 5095  2025-06-17  Argentina   NaN  83300.0  70.81  85700.0  73.02  79300.0
#
#       AL30C  AL30D  ...   TZXD7   TZX25   TZX28  X20Y4   TZXM6  S14O4  S29N4  \
# ...

# %% [markdown]
# # Solo algunas variables

# %%
url_base='https://api.alphacast.io/datasets'
dataset='6042'
select = '79353'
url = url_base + f'/{dataset}/data?apiKey={API_key}&$select={select}&$format=csv'

r1 = requests.get(url)

# %%
data = StringIO(r1.text)
df = pd.read_csv(data, delimiter=',')

# %%
df[-10:]
# Out:
#            Date    country  Sector privado no registrado
# 104  2024-06-01  Argentina                       2642.13
# 105  2024-07-01  Argentina                       3040.48
# 106  2024-08-01  Argentina                       3362.05
# 107  2024-09-01  Argentina                       3710.18
# 108  2024-10-01  Argentina                       3994.36
# 109  2024-11-01  Argentina                       4319.74
# 110  2024-12-01  Argentina                       4615.04
# 111  2025-01-01  Argentina                       5010.83
# 112  2025-02-01  Argentina                       5408.11
# 113  2025-03-01  Argentina                       5684.22

# %% [markdown]
# # Usando la librería

# %%
# !pip install alphacast
from alphacast import Alphacast

# %%
alphacast = Alphacast(userdata.get('ALPHACAST'))
dataset = alphacast.datasets.dataset(5515)


df = dataset.download_data(format = "pandas", startDate=None, endDate=None, filterVariables = ["75061"], filterEntities = {})

# %%
df
# Out:
#            Date    country  Alimentos y bebidas no alcohólicas
# 0    2016-12-01  Argentina                            100.0000
# 1    2017-01-01  Argentina                            101.3024
# 2    2017-02-01  Argentina                            103.1605
# 3    2017-03-01  Argentina                            106.0143
# 4    2017-04-01  Argentina                            108.3515
# ..          ...        ...                                 ...
# 97   2025-01-01  Argentina                           8278.1147
# 98   2025-02-01  Argentina                           8546.6547
# 99   2025-03-01  Argentina                           9051.2822
# 100  2025-04-01  Argentina                           9318.2093
# 101  2025-05-01  Argentina                           9365.3121
#
# [102 rows x 3 columns]
