# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/DataExtraction/blob/main/DatosGobAr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import urllib.parse
API_BASE_URL = "http://apis.datos.gob.ar/series/api/"

def get_api_call(ids, **kwargs):
    kwargs["ids"] = ",".join(ids)
    return "{}{}?{}".format(API_BASE_URL, "series", urllib.parse.urlencode(kwargs))

api_call = get_api_call(["143.3_NO_PR_2004_A_21"], start_date="2020-01")
print(api_call)
# Out:
# http://apis.datos.gob.ar/series/api/series?start_date=2020-01&ids=143.3_NO_PR_2004_A_21

# %%
datos=requests.get(api_call).json()

# %%
datos
# Out:
# {'data': [['2020-01-01', 133.89108610595727],
#   ['2020-02-01', 128.97363875350487],
#   ['2020-03-01', 128.2110607169644],
#   ['2020-04-01', 113.29503437158964],
#   ['2020-05-01', 131.02956916606604],
#   ['2020-06-01', 132.52196537198196],
#   ['2020-07-01', 127.46368980591409],
#   ['2020-08-01', 125.1838939015328],
#   ['2020-09-01', 127.17507561554577],
#   ['2020-10-01', 131.34550037216792],
#   ['2020-11-01', 132.06865461126827],
#   ['2020-12-01', 133.85436775869388],
#   ['2021-01-01', 131.52154429240738],
#   ['2021-02-01', 126.23926987488628],
#   ['2021-03-01', 145.95689030203587],
#   ['2021-04-01', 147.28081278944776],
#   ['2021-05-01', 151.16930917449497],
#   ['2021-06-01', 148.97966150197678],
#   ['2021-07-01', 142.42605450449912],
#   ['2021-08-01', 140.97500035145654],
#   ['2021-09-01', 141.2958880224631],
#   ['2021-10-01', 139.51411806931912],
#   ['2021-11-01', 143.75160757066374],
#   ['2021-12-01', 147.23078899671785],
# ...

# %%
import pandas as pd
pd.DataFrame(datos.get("data"), columns=['Fecha', 'EMAE'])
# Out:
#          Fecha        EMAE
# 0   2020-01-01  133.891086
# 1   2020-02-01  128.973639
# 2   2020-03-01  128.211061
# 3   2020-04-01  113.295034
# 4   2020-05-01  131.029569
# ..         ...         ...
# 58  2024-11-01  146.455509
# 59  2024-12-01  146.648778
# 60  2025-01-01  146.497551
# 61  2025-02-01  141.757277
# 62  2025-03-01  150.395244
#
# [63 rows x 2 columns]
